# %%
import pandas as pd

df = pd.read_csv('toorandmed.csv')

row_info = df.iloc[3]
pd.set_option('display.max_rows', None)
print(row_info)
# Out:
# course_uuid                                                                                9c7f4c4c-f4a5-4a5d-533e-7a85e99babcf
# code                                                                                                                LOKT.00.009
# title__en                                                                                                     Medical Chemistry
# version__title__en                                                                                            Medical Chemistry
# credits                                                                                                                     5.0
# overview__description__en                                                     A great deal of attention is given to the phys...
# version__overview__description__en                                            A great deal of attention is given to the phys...
# ...
